# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
## importando novo dataset com novas colunas (quantidade de observação, lat & lon, e aprovação do dado)

# %%
data1 = pd.read_csv('ebd_BR_relFeb-2021.txt', sep='\t', usecols = ['COMMON NAME', 'SCIENTIFIC NAME', 'OBSERVATION COUNT', 'LATITUDE','LONGITUDE' , 'OBSERVATION DATE', 'APPROVED'])

# %%
## procurando se existe dados reprovados

# %%
data2 = pd.read_csv('ebd_BR_relFeb-2021.txt', sep='\t', usecols = ['COMMON NAME', 'APPROVED'])

# %%
data2.describe()
# Out:
#         APPROVED
# count  8170994.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0

# %%
data2.['APPROVED'].value_counts()

# %%
data2['Cylinders'] == 0

# %%
data[data['Cylinders'] == 6]['Cylinders'].value_counts()

# %%
## x.mean() x.std() x.describe() (data_bkp = data1.copy())

# %%
data1.head(50)
# Out:
#                       COMMON NAME             SCIENTIFIC NAME  \
# 0                     Black Noddy               Anous minutus
# 1                     Brown Booby            Sula leucogaster
# 2                     Brown Noddy              Anous stolidus
# 3            Leach's Storm-Petrel       Oceanodroma leucorhoa
# 4         Magnificent Frigatebird         Fregata magnificens
# 5                 Manx Shearwater           Puffinus puffinus
# 6                      Sooty Tern        Onychoprion fuscatus
# 7                South Polar Skua    Stercorarius maccormicki
# 8                 Bulwer's Petrel           Bulweria bulwerii
# 9               Cory's Shearwater        Calonectris diomedea
# 10           Leach's Storm-Petrel       Oceanodroma leucorhoa
# 11        Magnificent Frigatebird         Fregata magnificens
# 12               Red-footed Booby                   Sula sula
# 13           Bar-breasted Piculet          Picumnus aurifrons
# ...
